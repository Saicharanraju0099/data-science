# %% [markdown]
# ### Matplotlib
# *Matplotlib is a powerful and widely-used open-source plotting library for the Python programming language. Its primary purpose is to create static, animated, and interactive visualizations of data.*

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
# Line plot
plt.plot(x,y,color = 'black', linestyle = '--', marker = 'o', markerfacecolor = 'red', markersize = 10)
plt.xlabel('Numbers')
plt.ylabel('Squares')
plt.title('Basic Line Plot')
plt.grid(True)

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [1,2,3,4,5]
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
plt.plot(x,y1,color = 'blue', marker = 'o')
plt.title('Plot 1: Squares')
# Out:
# Text(0.5, 1.0, 'Plot 1: Squares')

# %%
# Bar plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [3,7,3,9,10]
plt.bar(categories, values, color = 'green')
plt.xlabel('categories')
plt.ylabel('values')
plt.title('Basic Bar Plot')
# Out:
# Text(0.5, 1.0, 'Basic Bar Plot')

# %% [markdown]
# ### Histogram
#
# **Matplotlib is a popular Python library for creating static, interactive, and animated visualizations, and it provides a straightforward way to generate histograms.**

# %%
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Sample Data')
plt.show()

# %%
data = [2,4,5,6,2,3,4,5,7,8,2,3,5]
plt.hist(data, bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Sample Data')
plt.show()

# %%
# Scatter plot
x = [1,2,3,4,5,6,7]
y = [2,3,4,5,6,7,8]
plt.scatter(x,y, color = 'purple', marker='^')
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
plt.title('Basic Scatter Plot')
plt.show()

# %%
labels = ['Agriculture', 'Mining', 'Power Distribution', 'Education']
sizes = [15, 30, 45, 10]
explode = (0,0,0.1,0)
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors,explode=explode, shadow=True)
plt.title('Distribution of Categories')
plt.axis('equal')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('./data/coffee.csv')
data.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
total_revenvue = data.groupby('Day')['Units Sold'].sum()
total_revenvue
# Out:
# Day
# Friday       80
# Monday       40
# Saturday     80
# Sunday       80
# Thursday     70
# Tuesday      50
# Wednesday    60
# Name: Units Sold, dtype: int64

# %%
total_revenvue.plot(kind='bar', color = 'teal')
plt.xlabel('Day of the weeek')
plt.ylabel('Total Units Sold on Particular Day')
# Out:
# Text(0, 0.5, 'Total Units Sold on Particular Day')
