# %% [markdown]
# Python's logging module is a built-in, comprehensive framework for recording events that occur during program execution. It provides a standardized and flexible way to capture information about a program's behavior, which is crucial for debugging, monitoring, and troubleshooting.

# %%
import logging

# configure the logging settings
logging.basicConfig(
    level=logging.DEBUG
)

# log messages with different severity levels
logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

# %%
import logging

logging.basicConfig(
    filemode='w',
    filename='app.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y:%m:%d:%H:%M:%S',
    force=True   # This will reset existing log configuration
)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
