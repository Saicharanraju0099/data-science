-- %%
CREATE DATABASE schoolDB;
use schoolDB;
CREATE TABLE students(
    StudentID INT PRIMARY KEY,
    FirstName VARCHAR(50) NOT NULL,
    LastName  VARCHAR(50) NOT NULL,
    Age INT CHECK(Age > 3),
    Gender CHAR(1) CHECK(Gender in ('M', 'F')),
);
-- Out:
-- : Msg 1801, Level 16, State 3, Line 1
-- Database 'schoolDB' already exists. Choose a different database name.
-- : Msg 2714, Level 16, State 6, Line 3
-- There is already an object named 'students' in the database.
-- Total execution time: 00:00:00.009

-- %%
INSERT into students VALUES(1,'Sai','Charan',20,'M')
INSERT into students VALUES(2,'Sai','Ram',21,'M')
INSERT into students VALUES(3,'Anitha','sree',19,'F')

SELECT * from students;
-- Out:
-- The statement has been terminated.
-- The statement has been terminated.
-- (1 row affected)
-- (3 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>StudentID</th><th>FirstName</th><th>LastName</th><th>Age</th><th>Gender</th></tr><tr><td>1</td><td>Sai</td><td>Charan</td><td>20</td><td>M</td></tr><tr><td>2</td><td>Sai</td><td>Ram</td><td>21</td><td>M</td></tr><tr><td>3</td><td>Anitha</td><td>sree</td><td>19</td><td>F</td></tr></table>
-- : Msg 2627, Level 14, State 1, Line 2
-- Violation of PRIMARY KEY constraint 'PK__students__32C52A79EA4AA397'. Cannot insert duplicate key in object 'dbo.students'. The duplicate key value is (1).
-- : Msg 2627, Level 14, State 1, Line 3
-- Violation of PRIMARY KEY constraint 'PK__students__32C52A79EA4AA397'. Cannot insert duplicate key in object 'dbo.students'. The duplicate key value is (2).
