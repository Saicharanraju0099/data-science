# %% [markdown]
# ### What is Exception Handling in Python?
#
#
# **It’s basically Python’s way of saying:**
# **Something went wrong… but instead of throwing your whole program in the trash, I’ll give you a chance to deal with it like an adult.**
#
# **Instead of crashing on an error (like dividing by zero or opening a missing file), you can catch the error and handle it gracefully.**

# %% [markdown]
# ### what are exceptions
# **Exceptions in Python are basically runtime errors — signals that something unexpected happened while your program was running, and Python doesn’t know how to continue unless you handle it.**
#
# **They occur during execution (runtime), not during compilation (Python doesn’t have a strict compile step anyway).**
#
# ### Examples:
#
# **Trying to divide by zero → ZeroDivisionError**
#
# **Accessing a missing file → FileNotFoundError**
#
# **Converting "abc" to int → ValueError**
#
# **Accessing an index out of range → IndexError**

# %%
# Exception try,except block
try:
    a = b
except:
    print("The Variable has not been assigned")
# Out:
# The Variable has not been assigned

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
# Handling Error
try:
    a = b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    division = 1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator positive value")
# Out:
# division by zero
# Please enter the denominator positive value

# %%
try:
    division = 1/2
    a = b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator positive value")
except Exception as ex1:
    print(ex1)
    print("Name error exception got caught here")
# Out:
# name 'b' is not defined
# Name error exception got caught here

# %%
try:
    num = int(input("Enter a num: "))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)

# %%
# try,except,else block

try:
    num = int(input("Enter a num: "))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
# Out:
# The result is 2.5

# %%
# try,except,else and finally block 

try:
    num = int(input("Enter a num: "))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
finally:
    print("The excution is completed")
# Out:
# Enter denominator greater than 0
# The excution is completed

# %%
# file handling and exception handling
try:
    file = open('example.txt','r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print("The file is doesnot exist")
finally:
    if 'file' in locals() not in file.closed():
        file.close()
        print("File is closed")
# Out:
# The file is doesnot exist
