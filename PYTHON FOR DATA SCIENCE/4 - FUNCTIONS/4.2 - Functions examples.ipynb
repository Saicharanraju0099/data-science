# %% [markdown]
# **Function Examples**

# %% [markdown]
# **Example 1** **Temperature Conversion**

# %%
def temperature_converter(temp,unit):
    """This function converts the temperature between """
    if unit == 'C':
        return temp * 9/5 + 32 #celsius to fahrenheit
    
    elif unit == 'F':
        return temp -32 * 5/9 # fahrenheit to celsius
    else:
        return None
print(f"Celsius temperature to fahrenheit: ",temperature_converter(23,'C'))
print(f"Fahrenheit temperature to celsius: ",temperature_converter(40,'F'))
# Out:
# Celsius temperature to fahrenheit:  73.4
# Fahrenheit temperature to celsius:  22.22222222222222

# %% [markdown]
# **Example 2: Password Strength Checker**

# %%
def is_password_stronger(password):
    """This function checks password is strong or not"""
    if len(password) < 8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '$@!$%*&+_'for char in password):
        return False
    else:
        return True
    
# calling the function
print(is_password_stronger("PassWd"))
print(is_password_stronger("Pass123@*"))
# Out:
# False
# True

# %% [markdown]
# **Example 3 : Calculate the total cost of items in a shopping cart**

# %%
def calculate_total_cost(cart):
    total_cost = 0
    for item in cart:
        total_cost += item['price'] * item['quantity']
    return total_cost



# Cart data
cart = [
    {'name':'surfexcel','price':180,'quantity':2},
    {'name':'freedom oil','price':170,'quantity':2},
    {'name':'oranges','price':80,'quantity':2}
]

# calling the function
total_cost = calculate_total_cost(cart)
print(total_cost)
# Out:
# 860

# %% [markdown]
# **Example 4**
# **check if a string is palindrome**

# %%
def is_palindrome(s):
    s = s.lower().replace(" ","")
    return s==s[::-1]

print(is_palindrome("malayalam"))
print(is_palindrome("fresh"))
# Out:
# True
# False

# %% [markdown]
# **Example 5**
# **Factorial of a number using a recursion**

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
factorial(6)
# Out:
# 720

# %% [markdown]
# **Example 6:**
# **A function to read a file and count frequency of each word**

# %%
def count_word(file_path):
    word_count = {}
    with open(file_path, 'r') as file:
        for line in file: 
            words = line.split()
            for word in words:  
                word = word.lower().strip(string.punctuation) # type: ignore
                word_count[word] = word_count.get(word, 0) + 1
    return word_count

file_path = "/Users/saicharan/Datascience/PYTHON FOR DATA SCIENCE/FUNCTIONS/function testing.txt"
word_frequency = count_word(file_path)
print(word_frequency)
# Out:
# {'hello': 1, 'this': 1, 'is': 2, 'python': 1, 'coding': 1, 'fun': 1}

# %% [markdown]
# **Example 7:**
# **validate email address**

# %%
import re

def is_valid_email(email):

    pattern = r'^[\w\.-]+@[\w\.-]+\.\w{2,}$'
    return re.match(pattern, email) is not None

# Calling the function
email = "google@gmail.com"
if is_valid_email(email):
    print("Valid email")
else:
    print("Invalid email")
# Out:
# Valid email
