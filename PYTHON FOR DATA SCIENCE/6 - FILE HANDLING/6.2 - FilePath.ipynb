# %%
import os 
cwd = os.getcwd()
print(f"The current working Directory is {cwd}")
# Out:
# The current working Directory is /Users/saicharan/Datascience/PYTHON FOR DATA SCIENCE/6 - FILE HANDLING

# %%
## Creating a new directory
new_directory = "package"
os.mkdir(new_directory)
print(f"New Directory is {new_directory} is created")
# Out:
# New Directory is package is created

# %%
#Listing a Files and directories
items = os.listdir('.')
print(items)
# Out:
# ['destination.txt', '6.2 - FilePath.ipynb', 'example.bin', 'example.txt', '6.1-File Operations.ipynb', 'package']

# %%
# Joining Paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
# Joining Paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# /Users/saicharan/Datascience/PYTHON FOR DATA SCIENCE/6 - FILE HANDLING/folder/file.txt

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f"The path '{path}' exist ")
else:
    print(f"The path doesnot exist")
# Out:
# The path 'example.txt' exist

# %%
# checking if path is file or directory
import os 
path = 'example.txt'
if os.path.isfile(path):
    print(f"the path '{path}' is a file")
elif os.path.isdir(path):
    print(f"the path '{path}' is a directory")
else:
    print(f"the path '{path}' is neither file nor directory")
# Out:
# the path 'example.txt' is a file

# %%
# Getting a absolute path 
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /Users/saicharan/Datascience/PYTHON FOR DATA SCIENCE/6 - FILE HANDLING/example.txt
