# %% [markdown]
# Operators in Python are special symbols or keywords that perform operations on one or more operands (values or variables). They are fundamental for manipulating data, performing calculations, making comparisons, and controlling program flow.

# %%
# Arithmetic operators in python
a = 10
b = 5
result = a + b, a - b, a * b, a / b, a % b, a ** b, a // b
print("result  is : ", result)
# Out:
# result  is :  (15, 5, 50, 2.0, 0, 100000, 2)

# %%
# comparision operators in python
a = 10
b = 10
a == b
# Out:
# True

# %%
str1 = "hello"
str2 = "hello"
str1 == str2
# Out:
# True

# %%
str1 != str2
# Out:
# False

# %%
# Greater than operator
a = 10
b = 100
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
# greater than or equal to operator
num1 = 10
num2 = 20
num1 >= num2
# Out:
# False

# %% [markdown]
# **Logical operators**

# %%
#and,not,or operators
 
x = True
y = False
result = x and y
print(result)
# Out:
# False

# %%
x = True
y = True
result = x and y
print(result)
# Out:
# True

# %%
# or operator
x = True
y = False
result = x or y
print(result)
# Out:
# True

# %%
x = False
y = False
result = x or y
print(result)
# Out:
# False

# %%
# Not operator
x = True
result = not x
print(result)
# Out:
# False

# %%
x = False
result = not x
print(result)
# Out:
# True
