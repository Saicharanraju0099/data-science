# %% [markdown]
# **Python Data types are the classification or categorization of data items. It represents the kind of value that tells what operations can be performed on a particular data. Since everything is an object in Python programming, Python data types are classes and variables are instances (objects) of these classes.**

# %% [markdown]
# **The importance of data types in Python**
#
# **1.Defining data and operations**
#
# **2. Preventing errors and ensuring code reliability**
#
# **3. Optimizing memory usage**
#
# **4. Enhancing performance**
#
# **5. Improving code readability and maintainability**
#
# **6. Facilitating database interactions**

# %%
#integer
age = 20
type(age)
# Out:
# int

# %%
#floating point data type
height = 6.9
print(height)
type(height)
# Out:
# 6.9
# float

# %%
#string data type
name = "jordhan"
print(name)
type(name)
# Out:
# jordhan
# str

# %%
#boolean data types
is_student = True
print(is_student)
type(is_student)
# Out:
# True
# bool

# %%
a = 1
b = 1
print(a == b)
type(a == b)
# Out:
# True
# bool

# %%
# concatenation errors
result = "hello" + 1  # this will raise a TypeError
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # concatenation errors
# ----> 2 result = "hello" + 1  # this will raise a TypeError
#       3 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# typecasting and concatenation
result = "hello" + str(1)
print(result)
# Out:
# hello1

# %% [markdown]
# **In Python, a list is a built-in dynamic sized array (automatically grows and shrinks). We can store all types of items (including another list) in a list.**

# %%
a = [10, 20, "GfG", 40, True]
print(a)

# accessing elements in a list
print(a[0])  
print(a[1])  
print(a[2])  
print(a[3])  
print(a[4])
# Out:
# [10, 20, 'GfG', 40, True]
# 10
# 20
# GfG
# 40
# True

# %%
print(a[2])
print(a[1:-1])
# Out:
# GfG
# [20, 'GfG', 40]

# %% [markdown]
# **ADDING ELEMENTS**

# %%
# Initialize an empty list
a = []

# Adding 10 to end of list
a.append(10)  
print("After append(10):", a)  

# Inserting 5 at index 0
a.insert(0, 5)
print("After insert(0, 5):", a) 

# Adding multiple elements  [15, 20, 25] at the end
a.extend([15, 20, 25])  
print("After extend([15, 20, 25]):", a)
# Out:
# After append(10): [10]
# After insert(0, 5): [5, 10]
# After extend([15, 20, 25]): [5, 10, 15, 20, 25]

# %% [markdown]
# **UPDATING ELEMENTS**

# %%
A = [1,2,3,4,5]
A[1] = 20
print("After updating the second elements:", A)
# Out:
# After updating the second elements: [1, 20, 3, 4, 5]

# %% [markdown]
# **REMOVING ELEMENTS FROM LIST**

# %%
a = [10, 20, 30, 40, 50]

# Removes the first occurrence of 30
a.remove(30)  
print("After remove(30):", a)

# Removes the element at index 1 (20)
popped_val = a.pop(1)  
print("Popped element:", popped_val)
print("After pop(1):", a) 

# Deletes the first element (10)
del a[0]  
print("After del a[0]:", a)
# Out:
# After remove(30): [10, 20, 40, 50]
# Popped element: 20
# After pop(1): [10, 40, 50]
# After del a[0]: [40, 50]

# %% [markdown]
# **Iterating Over Lists**
#
# **We can iterate the Lists easily by using a for loop or other iteration methods.**

# %%
#using for loop 
a = ['apple', 'banana', 'cherry',1,2,3]

# Iterating over the list
for item in a:
    print(item)
# Out:
# apple
# banana
# cherry
# 1
# 2
# 3

# %%
# for loop
a = [1, 3, 5, 7, 9,11]

# On each iteration val
# represents the current item/element
for val in a:
    print(val)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
#for loop with range 
a = [0,2,4,6,8,10]
n = len(a)
for i in range(n):
    print(a[i])
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#while loop with range 
a = [0,2,4,6,8,10]
i = 0
while i < len(a):
    print(a[i])
    i += 1
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# **Using enumerate()**
#
#
# **We can also use the enumerate() function to iterate through the list. This method provides both the index (i) and the value (val) of each element during the loop.**

# %%
a = [0,2,4,6,8,10]
for b, val in enumerate(a):
    print(f"Index",{b}, "Values",{val})
# Out:
# Index {0} Values {0}
# Index {1} Values {2}
# Index {2} Values {4}
# Index {3} Values {6}
# Index {4} Values {8}
# Index {5} Values {10}

# %% [markdown]
# **Using List Comprehension**
#
#
# **List comprehension is similar to for loop. It provides the shortest syntax for looping through list.**

# %%
a = [0,2,4,6,8,10]
[print(val) for val in a]
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# [None, None, None, None, None, None]

# %% [markdown]
# **Nested Lists in Python**
#
# **A nested list is a list within another list, which is useful for representing matrices or tables. We can access nested elements by chaining indexes.**

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Access element at row 1, column 2
print(matrix[0][1])
# Out:
# 2

# %% [markdown]
# **List Comprehension in Python**
#
# **List comprehension is a concise way to create lists using a single line of code. It is useful for applying an operation or filter to items in an iterable, such as a list or range.**

# %%
# Create a list of squares from 1 to 5
squares = [x**2 for x in range(1, 6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# **Creating a String**
#
# **Strings can be created using either single (') or double (") quotes.**

# %%
s1 = 'sai'
s2 = "charan"
print(s1)
print(s2)
# Out:
# sai
# charan

# %% [markdown]
# **Multi-line Strings**
#
# **If we need a string to span multiple lines then we can use triple quotes (''' or """)**
