# %% [markdown]
# Example 1 : Manage a To do List
#
# **creating a to do list to keep track of tasks**

# %%
to_do_list = ["I need to buy a Groceries","Need to clean house","pay bills"]

# adding a task
to_do_list.append("schledule a meeting")
to_do_list.append("Go for a run")

#remove the task
to_do_list.remove("Need to clean house")

## checking task in the task
if "pay bills" in to_do_list:
    print("Donot forgot to pay the bills")

print("To do list remaining")

for  task in to_do_list:
    print(f"- {task}")
# Out:
# Donot forgot to pay the bills
# To do list remaining
# - I need to buy a Groceries
# - pay bills
# - schledule a meeting
# - Go for a run

# %% [markdown]
# Example 2: Organising Student Grades
#
#
# **Create a list to store and calculate average grades for students**

# %%
grades = [78,93,88,90,97,99]

#Adding a new grade 
grades.append(100)
#calculating average grade 
average_grade = sum(grades) / len(grades)
print(f"Average Grade: {average_grade:.2f} ")

# Finding a grades 
highest_grade = max(grades)
lowest_grade = min(grades)
print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Average Grade: 92.14
# Highest Grade: 100
# Lowest Grade: 78

# %% [markdown]
# Example 3: Managing An Inventory
#
# **Use a list to manage inventory items in a store**

# %%
# Managing a Inventory
inventory = ["Apples","Bananas","Oranges","Grapes"]

# adding a new item
inventory.append("watermelon")
# removing an item that is out of stock 
inventory.remove("Bananas")
# checking an item is in stock
item = "Oranges"
if item in inventory:
    print(f"{item} are in stock")
else:
    print(f"{item} are out of stock")
# Out:
# Oranges are in stock
