# %% [markdown]
# **Function Examples**

# %% [markdown]
# **Example 1** **Temperature Conversion**

# %%
def temperature_converter(temp,unit):
# Out:
#   Cell In[2], line 2
#
#     ^
# SyntaxError: incomplete input
