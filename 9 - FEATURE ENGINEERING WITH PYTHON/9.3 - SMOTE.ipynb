# %% [markdown]
# ### SMOTE : Synthetic Minority Oversampling Technique.
#
# **SMOTE creates synthetic (new) examples of the minority class rather than simply duplicating existing ones.**
# ⚖️ Why SMOTE is Needed
#
# In classification problems, an imbalanced dataset looks like this:
# | Class        | Count |
# | ------------ | ----- |
# | 0 (Majority) | 900   |
# | 1 (Minority) | 100   |

# %%
from sklearn.datasets import make_classification

# %%
x,y = make_classification(n_samples=1000,n_features=2, n_clusters_per_class=1,
                    weights=[0.90], random_state=2, n_redundant=0)

# %%
import pandas as pd
pd1 = pd.DataFrame(x, columns=['f1', 'f2'])
pd2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([pd1, pd2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -2.140340  0.562441       0
# 1 -0.519719 -1.932268       0
# 2 -0.794638  1.775431       0
# 3  0.223479  2.096700       0
# 4 -1.332802  0.637973       0

# %%
## Here we can see how many 0 and 1 are there in the target column
final_df['target'].value_counts()
# Out:
# target
# 0    897
# 1    103
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c = final_df['target'])

# %% [markdown]
# ### Transform The data set

# %%
from imblearn.over_sampling import SMOTE
oversampling = SMOTE()
x, y = oversampling.fit_resample(final_df[['f1', 'f2']], final_df['target'])
x.shape, y.shape
# Out:
# ((1794, 2), (1794,))

# %%
y[y==0]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: target, Length: 897, dtype: int64

# %%
len(y[y==0])
# Out:
# 897

# %%
y[y==1]
# Out:
# 16      1
# 36      1
# 38      1
# 45      1
# 51      1
#        ..
# 1789    1
# 1790    1
# 1791    1
# 1792    1
# 1793    1
# Name: target, Length: 897, dtype: int64

# %%
len(y[y==0])
# Out:
# 897

# %% [markdown]
# ### After Over sampling

# %%
import pandas as pd
pd1 = pd.DataFrame(x, columns=['f1', 'f2'])
pd2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([pd1, pd2], axis=1)

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c = final_df['target'])
